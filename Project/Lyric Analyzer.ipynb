# %%
import pandas as pd
import pip
import nltk
import re
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
songlist = pd.read_csv('allsongs_lyrkl.csv', header=0)

# %%
songlist.plot.

# %%
#print songlist

# %%
songlist.boxplot(column='lyrkl_score', by='Year')
plt.suptitle("")
plt.title('LYRKL Score by Year')
plt.xlabel('Year')
plt.ylabel('LYRKL Score')
#plt.show()
plt.savefig('LYRKL-Score-by-Year-BOXPLOT.png')

# %%
songlist_year = pd.DataFrame()

# %%
print songlist['lyrkl_score'].describe()
# Out:
# count    500.000000
# mean      49.569520
# std       30.421820
# min        1.028571
# 25%       27.617486
# 50%       41.984835
# 75%       61.457229
# max      211.480405
# Name: lyrkl_score, dtype: float64

# %%
songlist.groupby('Year').unique_word_counts.mean().plot.bar()
plt.show()

# %%
songlist.plot(kind='scatter', x='word_counts', y='unique_word_counts', alpha=0.5)
plt.suptitle("")
plt.title('WORD COUNT SCATTER PLOT 2011-2015')
plt.xlabel('Word Count')
plt.ylabel('Unique Word Count')
plt.ylim([0,450])
plt.xlim([0,1000])
plt.show() 
plt.savefig('WORD COUNT SCATTER PLOT 2011-2015.png')

# %%
songlist.word_counts.hist(by=songlist.Year, sharex=True, sharey=True)
plt.suptitle('Total Word Count Histograms')
plt.show()
plt.savefig('Total Word Count Histograms.png')

# %%
songlist.unique_word_counts.hist(by=songlist.Year, sharex=True, sharey=True)
plt.suptitle('Unique Word Count Histograms')
plt.show()
plt.savefig('Unique Word Count Histograms.png')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-97-a342e5b06120> in <module>()
# ----> 1 songlist.unique_word_counts.mean(by=songlist.Year, sharex=True, sharey=True)
#       2 plt.suptitle('Unique Word Count Histograms')
#       3 plt.show()
#       4 plt.savefig('Unique Word Count Histograms.png')
#
# /Users/PALMER/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in stat_func(self, axis, skipna, level, numeric_only, **kwargs)
#    5299     def stat_func(self, axis=None, skipna=None, level=None, numeric_only=None,
#    5300                   **kwargs):
# -> 5301         nv.validate_stat_func(tuple(), kwargs)
#    5302         if skipna is None:
#    5303             skipna = True
#
# /Users/PALMER/anaconda/lib/python2.7/site-packages/pandas/compat/numpy/function.pyc in __call__(self, args, kwargs, fname, max_fname_arg_count, method)
# ...

# %%
songlist.plot(kind='scatter', x='unique_word_counts', y='rank', alpha=0.5)
plt.show()

# %%
pd.scatter_matrix(songlist, figsize=(15,15))
plt.show()
